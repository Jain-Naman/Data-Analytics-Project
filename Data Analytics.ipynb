# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df1=pd.read_csv('C:/Users/Dheeraj/Desktop/Dheeraj/SEM 5 DATA ANALYTICS ASSIGNMENT/deliveries2.csv')

# %%
df1
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
#Find max and min dismissals
Unique=df1['fielder'].dropna()
Dissmissals=Unique.value_counts()
print('Max dismissals by',Dissmissals.head(1))
print('Min dismissals by',Dissmissals[Dissmissals==1])
# Out:
# Max dismissals by MS Dhoni    159
# Name: fielder, dtype: int64
# Min dismissals by JP Duminy (sub)          1
# M Santner                1
# RG More                  1
# LA Pomersbach (sub)      1
# M Lomror                 1
#                         ..
# NLTC Perera (sub)        1
# R Ninan                  1
# A Joseph                 1
# P Suyal                  1
# Shakib Al Hasan (sub)    1
# Name: fielder, Length: 93, dtype: int64

# %%
df1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#Counting each type of wicket
Out=df1['dismissal_kind'].dropna()
Wickets=Out.value_counts()
print('Max dismissals by',Wickets.head(1))
Wickets
# Out:
# Max dismissals by caught    5348
# Name: dismissal_kind, dtype: int64
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
#correlation between variables
df1.corr()
# Out:
#                match_id    inning      over      ball  is_super_over  \
# match_id       1.000000  0.003958  0.008268 -0.001349      -0.009150
# inning         0.003958  1.000000 -0.050076 -0.003943       0.084154
# over           0.008268 -0.050076  1.000000 -0.007424      -0.034329
# ball          -0.001349 -0.003943 -0.007424  1.000000      -0.001143
# is_super_over -0.009150  0.084154 -0.034329 -0.001143       1.000000
# wide_runs     -0.007549  0.001201 -0.010003 -0.004665      -0.001019
# bye_runs       0.000905 -0.000757  0.012111  0.006602       0.001353
# legbye_runs   -0.012429 -0.001996 -0.004764 -0.002727       0.001735
# noball_runs   -0.004623 -0.000904  0.016984  0.000567       0.013640
# penalty_runs  -0.001475  0.003442 -0.000979  0.000711      -0.000071
# batsman_runs   0.033510 -0.005362  0.086701  0.007950       0.010125
# extra_runs    -0.013323 -0.000531 -0.002479 -0.002576       0.003504
# total_runs     0.030727 -0.005485  0.086326  0.007414       0.010891
#
# ...

# %%
#Counting the number of times the person has gotten dismissed
Count=df1['player_dismissed'].dropna()
Wickets=Count.value_counts()
print("Player dismissed most number of times is",Wickets.head(1))
Wickets
# Out:
# Player dismissed most number of times is SK Raina    162
# Name: player_dismissed, dtype: int64
# SK Raina         162
# RG Sharma        155
# RV Uthappa       153
# V Kohli          143
# S Dhawan         137
#                 ...
# TM Srivastava      1
# P Chopra           1
# DE Bollinger       1
# SE Bond            1
# Basil Thampi       1
# Name: player_dismissed, Length: 487, dtype: int64

# %%
df2=pd.read_csv('C:/Users/Dheeraj/Desktop/Dheeraj/SEM 5 DATA ANALYTICS ASSIGNMENT/matches.csv')
df2
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
#Null values in every column
df2.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df2.corr()
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets
# id              1.000000  0.668304   -0.011658    -0.039403       -0.012239
# season          0.668304  1.000000   -0.001116    -0.037529       -0.009379
# dl_applied     -0.011658 -0.001116    1.000000    -0.016349       -0.011631
# win_by_runs    -0.039403 -0.037529   -0.016349     1.000000       -0.560420
# win_by_wickets -0.012239 -0.009379   -0.011631    -0.560420        1.000000

# %%
df3=pd.read_csv('C:/Users/Dheeraj/Desktop/Dheeraj/SEM 5 DATA ANALYTICS ASSIGNMENT/Overwise statistics without super over.csv')

# %%
df3
# Out:
#        match_id  inning         batting_team                 bowling_team  \
# 0           1.0     1.0  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1           1.0     1.0  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2           1.0     1.0  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3           1.0     1.0  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4           1.0     1.0  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...         ...     ...                  ...                          ...
# 30235   11415.0     2.0  Chennai Super Kings               Mumbai Indians
# 30236   11415.0     2.0  Chennai Super Kings               Mumbai Indians
# 30237   11415.0     2.0  Chennai Super Kings               Mumbai Indians
# 30238   11415.0     2.0  Chennai Super Kings               Mumbai Indians
# 30239   11415.0     2.0  Chennai Super Kings               Mumbai Indians
#
#        over  runs  wickets               winner
# ...

# %%
#statistics of every team that bats first
a=df3.groupby(['batting_team','winner'])
a.first()
# Out:
#                                                  match_id  inning  \
# batting_team        winner
# Chennai Super Kings Chennai Super Kings              61.0     1.0
#                     Deccan Chargers                  85.0     1.0
#                     Delhi Capitals                   79.0     1.0
#                     Kings XI Punjab                 190.0     2.0
#                     Kochi Tuskers Kerala            252.0     1.0
# ...                                                   ...     ...
# Sunrisers Hyderabad Mumbai Indians                   10.0     1.0
#                     Rajasthan Royals                416.0     1.0
#                     Rising Pune Supergiants          25.0     1.0
#                     Royal Challengers Bangalore     432.0     1.0
#                     Sunrisers Hyderabad               1.0     1.0
#
#                                                                 bowling_team  \
# batting_team        winner
# ...

# %%
#max number of times a team has won
Winner=df3['winner'].value_counts()
print("Most successful team",Winner.head(1))
Winner
# Out:
# Most successful team Mumbai Indians    4360
# Name: winner, dtype: int64
# Mumbai Indians                 4360
# Chennai Super Kings            4000
# Kolkata Knight Riders          3680
# Royal Challengers Bangalore    3360
# Kings XI Punjab                3280
# Delhi Capitals                 3080
# Rajasthan Royals               3000
# Sunrisers Hyderabad            2320
# Deccan Chargers                1160
# Rising Pune Supergiants         600
# Gujarat Lions                   520
# Pune Warriors                   480
# Kochi Tuskers Kerala            240
# Name: winner, dtype: int64
