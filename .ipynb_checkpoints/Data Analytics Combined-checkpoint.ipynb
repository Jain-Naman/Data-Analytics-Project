# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Deliveries2 file

# %%
df1=pd.read_csv('C:/Users/DELL/Desktop/PES/DA Project/deliveries2.csv')

# %%
df1.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  legbye_runs  \
# ...

# %%
#Find max and min dismissals

Unique=df1['fielder'].dropna()
Dissmissals=Unique.value_counts()
print('Max dismissals by',Dissmissals.head(1))
print('Min dismissals by',Dissmissals[Dissmissals==1])
# Out:
# Max dismissals by MS Dhoni    159
# Name: fielder, dtype: int64
# Min dismissals by Misbah-ul-Haq            1
# A Singh                  1
# PJ Sangwan (sub)         1
# TS Mills                 1
# T Mishra                 1
#                         ..
# S Midhun                 1
# R Bishnoi                1
# M Kaif (sub)             1
# Shakib Al Hasan (sub)    1
# L Ngidi                  1
# Name: fielder, Length: 93, dtype: int64

# %%
df1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#Counting each type of wicket

Out=df1['dismissal_kind'].dropna()
Wickets=Out.value_counts()
print('Max dismissals by',Wickets.head(1))
Wickets
# Out:
# Max dismissals by caught    5348
# Name: dismissal_kind, dtype: int64
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
#Counting the number of times the person has gotten dismissed

Count=df1['player_dismissed'].dropna()
Wickets=Count.value_counts()
print("Player dismissed most number of times is",Wickets.head(1))
Wickets
# Out:
# Player dismissed most number of times is SK Raina    162
# Name: player_dismissed, dtype: int64
# SK Raina           162
# RG Sharma          155
# RV Uthappa         153
# V Kohli            143
# S Dhawan           137
#                   ...
# SMSM Senanayake      1
# M Ntini              1
# VS Yeligati          1
# RR Bhatkal           1
# L Plunkett           1
# Name: player_dismissed, Length: 487, dtype: int64

# %% [markdown]
# # Loading Matches file

# %%
df2=pd.read_csv('C:/Users/DELL/Desktop/PES/DA Project/matches.csv')

# %%
#data cleaning, error detection in dataset

error=0
for i in range(len(df2['win_by_runs'])):
    if df2['win_by_runs'][i]> 0 and df2['win_by_wickets'][i]>0:
        error+=1
    else:
        pass

if error>0:
    print('Error')
else:
    print('No Error')
# Out:
# No Error

# %%
#cleaning the dataset
df=df2.drop(["id","venue","umpire1","umpire2","umpire3"],axis=1)

# %%
#Win percentage if team elects to field after winning toss

field_and_match_win=0
for i in range(len(df2['toss_winner'])):
    if (df2['toss_decision'][i] == 'field' and df2['toss_winner'][i]==df2['winner'][i]):
        field_and_match_win +=1

toss_and_match_win_percent=(field_and_match_win/756)*100
print("First field and match win percent is",toss_and_match_win_percent)
# Out:
# First field and match win percent is 34.25925925925926

# %%
#Win percentage if team elects to bat after winning toss

bat_and_match_win=0
for i in range(len(df2['toss_winner'])):
    if (df2['toss_decision'][i] == 'bat' and df2['toss_winner'][i]==df2['winner'][i]):
        bat_and_match_win +=1

toss_and_match_win_percent=(bat_and_match_win/756)*100
print("First bat and match win percent is",toss_and_match_win_percent)
# Out:
# First bat and match win percent is 17.724867724867725

# %%
#Win percentage if team wins toss

toss_and_match_win=0
for i in range(len(df2['toss_winner'])):
    if df2['toss_winner'][i]==df2['winner'][i]:
        toss_and_match_win +=1

toss_and_match_win_percent=(toss_and_match_win/756)*100
print("Percentage of team winning toss wins match", toss_and_match_win_percent,)
# Out:
# Percentage of team winning toss wins match 51.98412698412699

# %%
chennai_match_win=0
for i in range(len(df2['toss_winner'])):
    if (df2['toss_winner'][i]=='Chennai Super Kings' and df2['winner'][i]=='Chennai Super Kings'):
        chennai_match_win +=1

toss_and_match_win_percent=(chennai_match_win/756)*100
print("Toss winner is CSK and match winner is also CSK", toss_and_match_win_percent)
# Out:
# Toss winner is CSK and match winner is also CSK 7.5396825396825395

# %%
#Null values in every column

df2.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# # Loading Over file

# %%
df3=pd.read_csv('C:/Users/DELL/Desktop/PES/DA Project/over.csv')

# %%
#Plot of number of runs in an over

runs_plot=df3.groupby('over')["runs"].sum()

total_runs_plot= sns.barplot(data=df3,x=df3['over'],y=runs_plot)

# %%
#statistics of every team that bats first

a=df3.groupby(['batting_team','winner'])
a.first()
# Out:
#                                                  match_id  inning  \
# batting_team        winner
# Chennai Super Kings Chennai Super Kings                61       1
#                     Deccan Chargers                    85       1
#                     Delhi Capitals                     79       1
#                     Kings XI Punjab                   190       2
#                     Kochi Tuskers Kerala              252       1
# ...                                                   ...     ...
# Sunrisers Hyderabad Mumbai Indians                     10       1
#                     Rajasthan Royals                  416       1
#                     Rising Pune Supergiants            25       1
#                     Royal Challengers Bangalore       432       1
#                     Sunrisers Hyderabad                 1       1
#
#                                                                 bowling_team  \
# batting_team        winner
# ...

# %%
#max number of times a team has won

Winner=df3['winner'].value_counts()
print("Most successful team",Winner.head(1))
Winner
# Out:
# Most successful team Mumbai Indians    4360
# Name: winner, dtype: int64
# Mumbai Indians                 4360
# Chennai Super Kings            4000
# Kolkata Knight Riders          3680
# Royal Challengers Bangalore    3360
# Kings XI Punjab                3280
# Delhi Capitals                 3080
# Rajasthan Royals               3000
# Sunrisers Hyderabad            2320
# Deccan Chargers                1160
# Rising Pune Supergiants         600
# Gujarat Lions                   520
# Pune Warriors                   480
# Kochi Tuskers Kerala            240
# Name: winner, dtype: int64

# %%
#Plot of number of runs in an over

runs_plot=df3.groupby('over')["runs"].sum()

total_runs_plot= sns.barplot(data=df3,x=df3['over'],y=runs_plot)

# %%
#Plot of number of runs in an over

wickets_plot=df3.groupby('over')["wickets"].sum()

wicket_plot= sns.lineplot(data=df3,x=df3['over'],y=wickets_plot)

# %%
#batting first or batting second

batting_order=["Batting First", "Batting Second"]
Compare = [0,0]

for i in range(len(df3['inning'])):
    if(df3['batting_team'][i]==df3['winner'][i]):
        Compare[0]+=1
    else:
        Compare[1]+=1

batting_plot= sns.barplot(data=df3,x=batting_order,y=Compare)
